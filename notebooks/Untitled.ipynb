# %%
import streamlit as st
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow_hub as hub
import tensorflow as tf
import numpy as np
import time
import model
from image_manipulation import *


image = Image.open('linkedin_test.jpg')

# %%
output, output2 = model.predict_image(image)
# Out:
# None 1000 1000
# CMD: ../bin/linux/candidate_crops ../bin/fastgaze.vxm "/home/adrien.hernandez.17/image-crop-analysis/notebooks/image_user.jpeg" show_all_points 0.56 1.0 1.14 2.0 1.0
# 2021-09-16 02:01:55.959 INFO    root: (1000, 1000), [0.56, 1.0, 1.14, 2.0, 1.0], (225, 225)
# 2021-09-16 02:01:55.962 INFO    root: t=0: (225.0, 225.0, 8.58815)
# 2021-09-16 02:01:56.044 INFO    root: ar=0.56: (0, 0, 1000, 560)
# 2021-09-16 02:01:56.045 INFO    root: Gen: (0, 0, 1000, 560.0)
# 2021-09-16 02:01:56.059 INFO    root: score [95]: 100.0
# 2021-09-16 02:01:56.060 INFO    root: score: 81.54761904761905	threshold: 25.0	159	1
# 2021-09-16 02:01:56.096 INFO    root: ar=1.00: (0, 0, 1000, 1000)
# 2021-09-16 02:01:56.097 INFO    root: Gen: (0, 0, 1000.0, 1000)
# 2021-09-16 02:01:56.111 INFO    root: score [95]: 100.0
# 2021-09-16 02:01:56.112 INFO    root: score: 81.54761904761905	threshold: 25.0	159	1
# 2021-09-16 02:01:56.149 INFO    root: ar=1.14: (0, 0, 877, 1000)
# 2021-09-16 02:01:56.150 INFO    root: Gen: (0, 0, 877.0, 1000)
# 2021-09-16 02:01:56.164 INFO    root: score [95]: 100.0
# 2021-09-16 02:01:56.166 INFO    root: score: 81.54761904761905	threshold: 25.0	159	1
# 2021-09-16 02:01:56.203 INFO    root: ar=2.00: (0, 0, 500, 1000)
# 2021-09-16 02:01:56.204 INFO    root: Gen: (0, 0, 500.0, 1000)
# 2021-09-16 02:01:56.218 INFO    root: score [95]: 100.0
# 2021-09-16 02:01:56.219 INFO    root: score: 81.54761904761905	threshold: 25.0	159	1
# 2021-09-16 02:01:56.257 INFO    root: ar=1.00: (0, 0, 1000, 1000)
# 2021-09-16 02:01:56.259 INFO    root: Gen: (0, 0, 1000.0, 1000)
# 2021-09-16 02:01:56.272 INFO    root: score [95]: 100.0
# 2021-09-16 02:01:56.273 INFO    root: score: 81.54761904761905	threshold: 25.0	159	1
# CMD: ../bin/linux/candidate_crops ../bin/fastgaze.vxm "/home/adrien.hernandez.17/image-crop-analysis/notebooks/image_user.jpeg" show_all_points

# %%
output

# %%
output2

# %%
process_image(img_path, model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b75f56a8116e> in <module>
# ----> 1 process_image(img_path, model)
#
# NameError: name 'img_path' is not defined
